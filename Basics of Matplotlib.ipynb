# %%
import matplotlib.pyplot as plt
squares=[1,4,9,16]
plt.plot(squares)
plt.xlabel("Numbers -->")
plt.ylabel("Squares-->")
plt.show()

# %%
# Now we can also increase the width of this line
plt.plot(squares,linewidth=5)
plt.show()

# %%
# Creating Label and title
plt.plot(squares,linewidth=5,color="pink")
plt.title("Squares of Numbers",fontsize=25)
plt.xlabel("Numbers-->",fontsize=11)
plt.ylabel("Squares-->",fontsize=11)
# Set size of tick labels.
#plt.tick_params(axis='both', labelsize=14)

plt.show()

# %%
#Now we can see that for number 3 it is showing square as 16, which is not correct 
# So to fix it we will pass the datas of x-axis

input_val=[1,2,3,4]
plt.plot(input_val,squares,linewidth=5,color="pink")
plt.title("Squares of Numbers",fontsize=25)
plt.xlabel("Numbers-->",fontsize=11)
plt.ylabel("Squares-->",fontsize=11)
plt.show()

# %% [markdown]
# ## Scattering points

# %%
plt.scatter(2,4,s=100)
plt.xlabel("Number ")
plt.ylabel("Squares")
plt.title("Squares of Number")
# Out:
# Text(0.5, 1.0, 'Squares of Number')

# %%
# We can scatter more than one point also
plt.scatter(input_val,squares,s=100)
plt.plot(input_val,squares)
plt.xlabel("Number",fontsize=12)
plt.ylabel("Squares ",fontsize=12)
plt.title("Squares of Numbers ")
plt.show()

# %% [markdown]
# ## Calculating Data Automatically
# Writing out lists by hand can be inefficient, especially when we have many
# points. Rather than passing our points in a list, let’s use a loop in Python to
# do the calculations for us. Here’s how this would look with 1000 points:

# %%
x_values=list(range(1,1001))
y_values=[x**2 for x in x_values]
plt.scatter(x_values,y_values,s=4,color="black")
#plt.plot((x_values,y_values)
plt.xlabel("Numbers -->",fontsize=13)
plt.ylabel("Squares -->",fontsize=13)
plt.title("Square of a Number ",fontsize=20)
plt.show()

# %% [markdown]
# #### Removing Outlines from Data Points
# matplotlib lets you color points individually in a scatter plot. The default—
# blue dots with a black outline—works well for plots with a few points. But
# when plotting many points, the black outlines can blend together. To
# remove the outlines around points, pass the argument edgecolor='none'
# when you call scatter():
# plt.scatter(x_values, y_values, edgecolor='none', s=40)

# %%
plt.scatter(x_values,y_values,edgecolor="none",s=4)
plt.xlabel("Numbers -->",fontsize=13)
plt.ylabel("Squares -->",fontsize=13)
plt.title("Square of a Number ",fontsize=20)
plt.show()

# %%
# Defining custom colors , pass c= a color you need to print
plt.scatter(x_values,y_values,c='red',edgecolor="none",s=4)
#plt.plot((x_values,y_values)
plt.xlabel("Numbers -->",fontsize=13)
plt.ylabel("Squares -->",fontsize=13)
plt.title("Square of a Number ",fontsize=20)
plt.show()

# %% [markdown]
# ### Using a Colormap
# A colormap is a series of colors in a gradient that moves from a starting to
# ending color. Colormaps are used in visualizations to emphasize a pattern
# in the data. For example, you might make low values a light color and high
# values a darker color.
# The pyplot module includes a set of built-in colormaps. To use one of
# these colormaps, you need to specify how pyplot should assign a color to
# each point in the data set. Here’s how to assign each point a color based on
# its y-value:

# %%
plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues,
edgecolor='none', s=40)
plt.xlabel("Numbers -->",fontsize=13)
plt.ylabel("Squares -->",fontsize=13)
plt.title("Square of a Number ",fontsize=20)
#plt.show()
# TO save file automatically we can do this
plt.savefig('square_plot.png')  # Write this instead of show()

# %% [markdown]
# The first argument is a filename for the plot image, which will be saved
# in the same directory as scatter_squares.py. The second argument trims extra
# whitespace from the plot. If you want the extra whitespace around the plot,
# you can omit this argument.

# %% [markdown]
# ## Now lets try for cube

# %%
x_values=[1,2,3,4]
y_values=[1,8,27,64]
plt.scatter(x_values,y_values,s=20)
plt.xlabel("Numbers-->",fontsize=12)
plt.ylabel("Cube ---> ",fontsize=12)
plt.title("Numbers and there Cubes")
plt.show()

# %%
# Now for first 2000 numbers
x_values=list(range(1,2001))
y_values=[x**3 for x in x_values]
plt.scatter(x_values,y_values,c=y_values,cmap=plt.cm.Blues)
plt.xlabel("Numbers-->>",fontsize=12)
plt.ylabel("Cubes --> ",fontsize=12)
plt.show()
